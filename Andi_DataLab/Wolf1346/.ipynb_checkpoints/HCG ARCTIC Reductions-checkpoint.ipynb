# %%
#reducing May 2017 ARCTIC run
from astropy.io import fits
import numpy as np

# Set up matplotlib and use a nicer set of plot parameters

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# %%
hdulist = fits.open('bias.0002.fits')

# %%
hdulist.info()
# Out:
# Filename: bias.0002.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU      89   (2102, 2050)   int16 (rescales to uint16)

# %%
# to display the full header
hdulist[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 2102 / length of data axis 1
# NAXIS2  =                 2050 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# OBSERVAT= 'APO'                / Per the IRAF observatory list.
# TELESCOP= '3.5m'
# INSTRUME= 'arctic'             / Instrument name
# LATITUDE= +3.2780361000000E+01 / Latitude of telescope base
# LONGITUD= -1.0582041700000E+02 / Longitude of telescope base
# TIMESYS = 'TAI'                / Time system for DATE-OBS
# UTC-TAI = -37.0                / UTC = TAI + UTC_TAI(seconds)
# UT1-TAI = -36.61               / UT1 = TAI + UT1_TAI(seconds)
# LST     = '16:14:22.849'       / Local Apperent Sidereal time
# OBJNAME = 'J114335+284532'     / Object name, per TCC ObjName
# ...

# %%
raw_image=hdulist[0].data

# %%
plt.imshow(raw_image, cmap='Dark2', norm=LogNorm())
plt.show()

# %%
print('Min:', np.min(raw_image))
print('Max:', np.max(raw_image))
print('Mean:', np.mean(raw_image))
print('Stdev:', np.std(raw_image))
# Out:
# ('Min:', 304)
# ('Max:', 65535)
# ('Mean:', 352.54724536446128)
# ('Stdev:', 115.26831314525171)

# %%
# I want to see if there is any trend in the bias over time
# So I need to read in all the bias frames and plot their bias values

# %%
print(type(raw_image.flatten()))
# Out:
# <type 'numpy.ndarray'>

# %%
NBINS = 50
histogram = plt.hist(raw_image.flatten(), NBINS, range=(320,380))
plt.show()

# %%
import ccdproc
from astropy import units as u

# %%
# I need to clean up the overscan regions in our quad readout. I'm going to try that using ccdproc for a different
# way of reading in/handling the images

# %%
# ALSO: The M filter cuts off hard and its pretty obvious I think in the flats. (and with a weird corner effect)
