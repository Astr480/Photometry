# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
import photutils

# %%
bias_6 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/bias.0006.fits')[0].data
print(bias_6.mean())
bias_7 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/bias.0007.fits')[0].data
print(bias_7.mean())
bias_8 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/bias.0008.fits')[0].data
print(bias_8.mean())
bias_9 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/bias.0009.fits')[0].data
print(bias_9.mean())
bias_10 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/bias.0010.fits')[0].data
print(bias_10.mean())
bias_11 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/bias.0011.fits')[0].data
print(bias_11.mean())
bias_12 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/bias.0012.fits')[0].data
print(bias_12.mean())
bias_13 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/bias.0013.fits')[0].data
print(bias_13.mean())
bias_14 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/bias.0014.fits')[0].data
print(bias_14.mean())
bias_15 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/bias.0015.fits')[0].data
print(bias_15.mean())
bias_16 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/bias.0016.fits')[0].data
print(bias_16.mean())
# Out:
# 351.70354319927594
# 351.3568139518693
# 351.65315007774245
# 351.7383458262746
# 351.675116381611
# 351.7116537095913
# 351.40129446984287
# 351.67762200923625
# 351.6943257292706
# 351.5752312547864
# 351.4999043883874

# %%
master_bias = (bias_6 + bias_7 + bias_8 + bias_9 + bias_10 + bias_11 + bias_12 + bias_13 + bias_14 + bias_15 + bias_16)/11
print(master_bias)
print(master_bias.mean())
print(master_bias.min())
print(master_bias.max())
# Out:
# [[ 317.27272727  315.90909091 1549.45454545 ... 1106.27272727
#    338.54545455  338.54545455]
#  [ 303.45454545  302.          333.45454545 ...  342.
#    309.09090909  309.36363636]
#  [ 313.63636364  311.63636364  342.         ...  349.54545455
#    316.72727273  316.81818182]
#  ...
#  [ 318.36363636  316.36363636  347.63636364 ...  350.
#    318.54545455  319.27272727]
#  [ 306.09090909  306.18181818  335.81818182 ...  340.09090909
#    307.90909091  308.27272727]
#  [ 327.09090909  327.18181818 1315.63636364 ... 1637.36363636
#    333.18181818  333.90909091]]
# 351.47656093552536
# 80.54545454545455
# 5956.818181818182

# %%
image_0001 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/wolf1346_.0001.fits')[0].data
print(image_0001)
print(image_0001.mean())
print(image_0001.min())
print(image_0001.max())
# Out:
# [[310 306 487 ... 562 355 347]
#  [289 290 495 ... 518 292 294]
#  [302 298 514 ... 519 300 304]
#  ...
#  [307 305 506 ... 518 307 306]
#  [295 293 496 ... 509 300 298]
#  [315 323 502 ... 540 338 334]]
# 643.8076900048734
# 289
# 65535

# %%
image_0001_sansbias = image_0001 - master_bias
print(image_0001_sansbias)
print(image_0001_sansbias.mean())
print(image_0001_sansbias.min())
print(image_0001_sansbias.max())
# Out:
# [[-7.27272727e+00 -9.90909091e+00 -1.06245455e+03 ... -5.44272727e+02
#    1.64545455e+01  8.45454545e+00]
#  [-1.44545455e+01 -1.20000000e+01  1.61545455e+02 ...  1.76000000e+02
#   -1.70909091e+01 -1.53636364e+01]
#  [-1.16363636e+01 -1.36363636e+01  1.72000000e+02 ...  1.69454545e+02
#   -1.67272727e+01 -1.28181818e+01]
#  ...
#  [-1.13636364e+01 -1.13636364e+01  1.58363636e+02 ...  1.68000000e+02
#   -1.15454545e+01 -1.32727273e+01]
#  [-1.10909091e+01 -1.31818182e+01  1.60181818e+02 ...  1.68909091e+02
#   -7.90909091e+00 -1.02727273e+01]
#  [-1.20909091e+01 -4.18181818e+00 -8.13636364e+02 ... -1.09736364e+03
#    4.81818182e+00  9.09090909e-02]]
# 292.3311290693482
# -5347.818181818182
# 65192.818181818184

# %%
plt.imshow(image_0001,cmap=plt.cm.gray)

# %%
plt.imshow(image_0001_sansbias,cmap=plt.cm.gray)

# %%
print(image_0001_sansbias.shape)
print(np.median(image_0001_sansbias[1022]))
print(np.median(image_0001_sansbias[1023]))
print(np.median(image_0001_sansbias[1024])) #overscan
print(np.median(image_0001_sansbias[1025])) #overscan
print(np.median(image_0001_sansbias[1026]))
print(np.median(image_0001_sansbias[1027]))
print()
print(np.median(image_0001_sansbias.transpose()[1020]))
print(np.median(image_0001_sansbias.transpose()[1030]))
print(np.median(image_0001_sansbias.transpose()[1040]))
print(np.median(image_0001_sansbias.transpose()[1050]))
print(np.median(image_0001_sansbias.transpose()[1060]))
print(np.median(image_0001_sansbias.transpose()[1070]))
print(np.median(image_0001_sansbias.transpose()[1080]))
print()
print(np.median(image_0001_sansbias.transpose()[1021]))
print(np.median(image_0001_sansbias.transpose()[1022]))
print(np.median(image_0001_sansbias.transpose()[1023]))
print(np.median(image_0001_sansbias.transpose()[1024]))
print(np.median(image_0001_sansbias.transpose()[1025]))
print(np.median(image_0001_sansbias.transpose()[1026])) #overscan region start
print(np.median(image_0001_sansbias.transpose()[1027]))
print(np.median(image_0001_sansbias.transpose()[1028]))
print(np.median(image_0001_sansbias.transpose()[1029]))
print()
print(2102-(2 * 1026)) #overscan region length
print(np.median(image_0001_sansbias.transpose()[2102-1026]))
print(np.median(image_0001_sansbias.transpose()[2102-1027])) #overscan region end
print(2102 - 1027) #overscan region end value
# Out:
# (2050, 2102)
# 300.1818181818182
# 300.6363636363636
# 3.272727272727252
# 4.545454545454561
# 304.09090909090907
# 304.8181818181818
#
# 295.90909090909093
# -1.545454545454561
# -2.545454545454561
# -3.0
# -1.727272727272748
# -0.45454545454543904
# 298.3636363636364
#
# 295.72727272727275
# 295.8181818181818
# 295.54545454545456
# 295.72727272727275
# 295.0
# 4.909090909090935
# -1.545454545454561
# -1.545454545454561
# -1.5909090909090935
#
# 50
# 298.45454545454544
# 6.818181818181813
# 1075

# %%
image_0001_sansbias_sansoverscan = np.delete(image_0001_sansbias,(0,1,1026,1027,1028,1029,1030,1031,1032,1033,1034,1035,1036,1037,1038,1039,1040,1041,1042,1043,1044,1045,1046,1047,1048,1049,1050,1051,1052,1053,1053,1054,1055,1056,1057,1058,1059,1060,1061,1062,1063,1064,1065,1066,1067,1068,1069,1070,1071,1072,1073,1074,1075,2051,2052), axis=1) #delete column
image_0001_sansbias_sansoverscan = np.delete(image_0001_sansbias_sansoverscan,(1024,1025), axis=0) #delete row
print(image_0001_sansbias_sansoverscan.shape)
# Out:
# (2048, 2048)

# %%
plt.imshow(image_0001_sansbias_sansoverscan,cmap=plt.cm.gray)

# %%
flat_5 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0005.fits')[0].data
flat_6 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0006.fits')[0].data
flat_7 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0007.fits')[0].data
flat_8 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0008.fits')[0].data
flat_9 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0009.fits')[0].data
flat_10 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0010.fits')[0].data
flat_11 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0011.fits')[0].data
flat_12 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0012.fits')[0].data
flat_13 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0013.fits')[0].data
flat_14 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0014.fits')[0].data
flat_15 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0015.fits')[0].data
flat_16 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0016.fits')[0].data
flat_17 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0017.fits')[0].data
flat_18 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0018.fits')[0].data
flat_19 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0019.fits')[0].data
flat_20 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0020.fits')[0].data
flat_21 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0021.fits')[0].data
flat_22 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0022.fits')[0].data
flat_23 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0023.fits')[0].data
flat_24 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0024.fits')[0].data
flat_25 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0025.fits')[0].data
flat_26 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0026.fits')[0].data
flat_27 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0027.fits')[0].data
flat_28 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0028.fits')[0].data
flat_29 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0029.fits')[0].data
flat_30 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0030.fits')[0].data
flat_31 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0031.fits')[0].data
flat_32 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0032.fits')[0].data
flat_33 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0033.fits')[0].data
flat_34 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0034.fits')[0].data
flat_35 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0035.fits')[0].data
flat_36 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0036.fits')[0].data
flat_37 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0037.fits')[0].data
flat_38 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0038.fits')[0].data
flat_39 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0039.fits')[0].data
flat_40 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0040.fits')[0].data
flat_41 = fits.open('/astro/users/chrism99/Desktop/LJ/Wolf1346/flat.0041.fits')[0].data

# %%
master_flat_washm = (flat_5 + flat_6 + flat_7 + flat_8 + flat_9 + flat_10 + flat_11 + flat_12 + flat_13 + flat_14 + flat_15 + flat_16)/12
master_flat_jcrc = (flat_17 + flat_18 + flat_19 + flat_20 + flat_21 + flat_22 + flat_23 + flat_24 + flat_25 + flat_26 + flat_27 + flat_28 + flat_29 + flat_30 + flat_31 + flat_32 + flat_33 + flat_34 + flat_35 + flat_36 + flat_37 + flat_38 + flat_39 + flat_40 + flat_41)/26
print(master_flat_washm)
print()
print(master_flat_jcrc)
print()
print(master_flat_washm.mean())
print(master_flat_washm.min())
print(master_flat_washm.max())
print()
print(master_flat_jcrc.mean())
print(master_flat_jcrc.min())
print(master_flat_jcrc.max())
# Out:
# [[318.41666667 317.08333333 427.33333333 ... 473.         342.91666667
#   344.58333333]
#  [290.83333333 288.83333333 392.16666667 ... 412.58333333 297.41666667
#   296.91666667]
#  [301.83333333 300.33333333 403.58333333 ... 419.41666667 304.75
#   305.5       ]
#  ...
#  [309.16666667 307.08333333 379.58333333 ... 379.91666667 307.75
#   309.5       ]
#  [297.5        297.5        369.16666667 ... 372.33333333 298.91666667
#   300.16666667]
#  [334.91666667 333.25       417.5        ... 410.5        335.58333333
#   335.91666667]]
#
# [[  50.65384615   43.26923077  781.92307692 ... 1143.46153846
#   1389.07692308 1299.15384615]
#  [ 320.38461538  318.03846154 1445.76923077 ...  583.23076923
#    317.23076923  318.61538462]
#  [ 323.69230769  325.07692308 1479.73076923 ...  594.26923077
#    319.69230769  319.73076923]
#  ...
#  [ 323.96153846  323.30769231 2256.34615385 ... 1092.57692308
#    325.65384615  324.88461538]
# ...

# %%
print(image_0001_sansbias_sansoverscan)
print(image_0001_sansbias_sansoverscan.mean())
print(image_0001_sansbias_sansoverscan.min())
print(image_0001_sansbias_sansoverscan.max())
# Out:
# [[-1.06245455e+03 -1.03945455e+03 -9.99181818e+02 ... -5.44272727e+02
#    1.64545455e+01  8.45454545e+00]
#  [ 1.61545455e+02  1.64545455e+02  1.59090909e+02 ...  1.76000000e+02
#   -1.70909091e+01 -1.53636364e+01]
#  [ 1.72000000e+02  1.61090909e+02  1.50454545e+02 ...  1.69454545e+02
#   -1.67272727e+01 -1.28181818e+01]
#  ...
#  [ 1.58363636e+02  1.49636364e+02  1.57363636e+02 ...  1.68000000e+02
#   -1.15454545e+01 -1.32727273e+01]
#  [ 1.60181818e+02  1.63181818e+02  1.78909091e+02 ...  1.68909091e+02
#   -7.90909091e+00 -1.02727273e+01]
#  [-8.13636364e+02 -8.07727273e+02 -7.56181818e+02 ... -1.09736364e+03
#    4.81818182e+00  9.09090909e-02]]
# 299.8602316162804
# -5347.818181818182
# 65192.818181818184

# %%
finder = photutils.DAOStarFinder(300, 3, ratio=1.0, theta=0.0, sigma_radius=1.5, sharplo=0.2, sharphi=1.0, roundlo=-1.0, roundhi=1.0, sky=0.0, exclude_border=False, brightest=None, peakmax=None).find_stars(image_0001_sansbias_sansoverscan, mask=None)

# %%
finder[1]
# Out:
# <Row index=1>
#   id      xcentroid          ycentroid          sharpness          roundness1          roundness2       npix   sky     peak         flux                mag
# int64      float64            float64            float64            float64             float64        int64 float64 float64      float64             float64
# ----- ------------------ ------------------ ------------------ ------------------ -------------------- ----- ------- ------- ------------------ -------------------
#     2 1722.4474238559283 16.069415223697977 0.4133663023699245 0.5005473481979771 -0.18304421425836112    25     0.0  1292.0 1.5709930273753099 -0.4904356437279611

# %%
fig,ax = plt.subplots(1,1)                    # One window
fig.set_size_inches(11,8.5)                   # (width,height) - letter paper landscape

fig.tight_layout()                            # Make better use of space on plot
ax.imshow(image_0001_sansbias_sansoverscan, cmap=plt.cm.gray, vmax=20000)
ax.scatter(finder["xcentroid"], finder["ycentroid"],facecolors=(1,1,1,0), edgecolors="r",s=100)

# %%
finder_200 = photutils.DAOStarFinder(1539, 5, ratio=1.0, theta=0.0, sigma_radius=1.5, sharplo=0.2, sharphi=1.0, roundlo=-1.0, roundhi=1.0, sky=0.0, exclude_border=False, brightest=None, peakmax=None).find_stars(image_0001_sansbias_sansoverscan, mask=None)
print(finder_200)
# Out:
#  id     xcentroid      ...        flux                 mag
# --- ------------------ ... ------------------ ---------------------
#   1 2003.5843729774845 ...  5.782436335527316   -1.9052771497452559
#   2 1091.6814875530765 ... 1.2695200792975008   -0.2590989356496822
#   3  1831.452146628438 ... 3.2939147793566916   -1.2942808971223596
#   4 1241.9796802351734 ... 1.0216398225346932  -0.02324453241307118
#   5 1674.9974422786306 ... 2.7672780477155774   -1.1051319948182727
#   6 1874.0846970131697 ...  22.13106719337069   -3.3625058919145157
#   7 1483.4623727164603 ... 1.0706495671661138  -0.07411836440447972
#   8   727.052774164629 ... 1.1975938267652357  -0.19577387170943483
#   9  553.2632590033065 ... 4.3248217084647536   -1.5899205207587532
#  10 1297.2991736392325 ... 1.0215071981013795 -0.023103578142397423
# ...                ... ...                ...                   ...
# 190 1884.3719864802808 ...  7.364220649535932   -2.1678169813019266
# ...

# %%
fig,ax = plt.subplots(1,1)                    # One window
fig.set_size_inches(11,8.5)                   # (width,height) - letter paper landscape

fig.tight_layout()                            # Make better use of space on plot
ax.imshow(image_0001_sansbias_sansoverscan, cmap=plt.cm.gray, vmax=10000)
ax.scatter(finder_200["xcentroid"], finder_200["ycentroid"],facecolors=(1,1,1,0), edgecolors="r",s=100)

# %%
circular_app = photutils.CircularAperture((finder["xcentroid"],finder["ycentroid"]),5)
#.CircularMaskMixin(method='center', subpixels=1)
#.CircularAperture((finder["xcentroid"],finder["ycentroid"]),5)
aperature_phot = photutils.aperture_photometry(image_0001_sansbias_sansoverscan,circular_app, error=None, mask=None, method='subpixel', subpixels=10, unit=None, wcs=None)
aperature_phot
# Out:
# <QTable length=343>
#   id       xcenter            ycenter          aperture_sum
#              pix                pix
# int64      float64            float64            float64
# ----- ------------------ ------------------ ------------------
#     1 2003.6057789937897 3.7869803659664956 171917.22363636363
#     2 1722.4474238559283 16.069415223697977  44885.70090909091
#     3  1091.651609053048 18.341801839513703 58221.090000000004
#     4 1831.2881432892395  32.55356772458595 119438.62545454546
#     5 1455.5698173500343  33.52083246530607  22155.63090909091
#     6  1241.931990943999  57.50685224876446  50045.34454545454
#     7 1674.9612323820727  58.15763652650606          101159.37
#     8 1120.6229173447323  61.26916552537855  36746.13181818181
#     9 1874.0565282118926   61.1097346918885          664152.26
#   ...                ...                ...                ...
#   334 1235.1238551892848  2012.809149827312  34607.43818181818
# ...

# %%
fig,ax = plt.subplots(1,1)                    # One window
fig.set_size_inches(11,8.5)                   # (width,height) - letter paper landscape

fig.tight_layout()                            # Make better use of space on plot
ax.imshow(image_0001_sansbias_sansoverscan, cmap=plt.cm.gray, vmax=10000)
ax.scatter(aperature_phot["xcenter"], aperature_phot["ycenter"],facecolors=(1,1,1,0), edgecolors="r",s=100)

# %%
circular_ann = photutils.CircularAnnulus((finder["xcentroid"],finder["ycentroid"]),5,6)
aperature_phot_ann = photutils.aperture_photometry(image_0001_sansbias_sansoverscan,circular_ann, error=None, mask=None, method='subpixel', subpixels=10, unit=None, wcs=None)
aperature_phot_ann
# Out:
# <QTable length=343>
#   id       xcenter            ycenter          aperture_sum
#              pix                pix
# int64      float64            float64            float64
# ----- ------------------ ------------------ ------------------
#     1 2003.6057789937897 3.7869803659664956 10916.336363636363
#     2 1722.4474238559283 16.069415223697977  9455.403636363637
#     3  1091.651609053048 18.341801839513703 11570.244545454545
#     4 1831.2881432892395  32.55356772458595 14244.941818181818
#     5 1455.5698173500343  33.52083246530607   8619.65818181818
#     6  1241.931990943999  57.50685224876446  11333.17818181818
#     7 1674.9612323820727  58.15763652650606 13622.459090909091
#     8 1120.6229173447323  61.26916552537855           10407.64
#     9 1874.0565282118926   61.1097346918885           50931.41
#   ...                ...                ...                ...
#   334 1235.1238551892848  2012.809149827312 10143.470909090907
# ...

# %%
aperature_phot['aperture_sum'] - aperature_phot_ann['aperture_sum']
# Out:
# <Column name='aperture_sum' dtype='float64' length=343>
# 161000.88727272727
#  35430.29727272727
#  46650.84545454546
# 105193.68363636364
# 13535.972727272729
#  38712.16636363637
#   87536.9109090909
# 26338.491818181814
#          613220.85
# 33532.214545454546
#  41343.81181818181
# 27671.456363636364
#                ...
# 31130.711818181822
#  37028.32181818182
#  24463.96727272727
#  33322.87636363636
# 200797.13181818184
#  266519.0363636364
# 108055.55454545456
# 26850.261818181818
#  29965.86727272727
# 22717.147272727278
# 57196.522727272735
# 13930.253636363635

# %%
fig,ax = plt.subplots(1,1)                    # One window
fig.set_size_inches(11,8.5)                   # (width,height) - letter paper landscape

fig.tight_layout()                            # Make better use of space on plot
ax.scatter(aperature_phot['id'], aperature_phot['aperture_sum'],facecolors=(1,1,1,0), edgecolors="r",s=100)
ax.scatter(aperature_phot_ann['id'], aperature_phot_ann['aperture_sum'],facecolors=(1,1,1,0), edgecolors="g",s=100)
ax.scatter(aperature_phot['id'], (aperature_phot['aperture_sum'] - aperature_phot_ann['aperture_sum']),facecolors=(1,1,1,0), edgecolors="b",s=100)

# %%
Background = photutils.background.Background2D(image_0001_sansbias_sansoverscan, 10)
Background

# %%
from astropy.stats import sigma_clipped_stats
from photutils import datasets
from photutils import DAOStarFinder
import matplotlib.pyplot as plt
from astropy.visualization import SqrtStretch
from astropy.visualization.mpl_normalize import ImageNormalize
from photutils import CircularAperture
from photutils import DAOStarFinder
from astropy.stats import sigma_clipped_stats
from photutils.datasets import make_100gaussians_image
from photutils import find_peaks
import matplotlib.pyplot as plt
from astropy.visualization import simple_norm
from astropy.visualization.mpl_normalize import ImageNormalize
from photutils import CircularAperture

# %%
data = image_0001_sansbias_sansoverscan
mean, median, std = sigma_clipped_stats(data, sigma=3.0)    
print((mean, median, std))
# Out:
# (289.0881082082253, 292.54545454545456, 22.69306064837286)

# %%
daofind = DAOStarFinder(fwhm=3.0, threshold=5.*std)    
sources = daofind(data - median)    
for col in sources.colnames:    
    sources[col].info.format = '%.8g'  # for consistent table output
print(sources)
# Out:
#  id xcentroid ycentroid sharpness  ... sky    peak      flux       mag
# --- --------- --------- ---------- ... --- --------- --------- -----------
#   1 2003.6058 3.7869804 0.43118611 ...   0 6695.5455 28.992086  -3.6556987
#   2 1890.5903 5.1577062 0.34135303 ...   0 249.72727 1.6300231 -0.53048441
#   3 1963.4284 5.2506294 0.50348624 ...   0 257.36364 1.4978835 -0.43869509
#   4 2018.4621 6.0634327 0.45051065 ...   0 189.27273 1.3008108 -0.28553535
#   5 439.07581 9.8544569 0.49278327 ...   0 396.72727 2.0915519 -0.80117161
#   6 1722.4474 16.069415  0.4133663 ...   0 999.45455 4.1536742  -1.5460811
#   7 1091.6516 18.341802 0.48511435 ...   0 1513.8182 6.3370047  -2.0047101
#   8 1324.3449  21.54621  0.5040428 ...   0 247.09091 1.2386286 -0.23235278
#   9 1831.2881 32.553568 0.41249695 ...   0      3885 16.304334  -3.0307577
#  10 1991.8986 33.467584 0.43701059 ...   0 322.90909 2.1189128  -0.8152827
# ...       ...       ...        ... ... ...       ...       ...         ...
# ...

# %%
positions = (sources['xcentroid'], sources['ycentroid'])
apertures = CircularAperture(positions, r=4.)
norm = ImageNormalize(stretch=SqrtStretch())
plt.imshow(data, cmap='Greys', origin='lower', norm=norm)
apertures.plot(color='blue', lw=1.5, alpha=0.5)

# %%
data = make_100gaussians_image()
mean, median, std = sigma_clipped_stats(data, sigma=3.0)
threshold = median + (5. * std)
tbl = find_peaks(data, threshold, box_size=11)
tbl['peak_value'].info.format = '%.8g'  # for consistent table output
print(tbl[:10])    # print only the first 10 peaks
# Out:
# x_peak y_peak peak_value
# ------ ------ ----------
#    233      0  27.477852
#    493      6  20.404769
#    207     11  24.075798
#    258     12  17.395025
#    366     12  18.729726
#    289     22  35.853276
#    380     29  19.261986
#    442     31  30.239994
#    359     36  19.771626
#    471     38   25.45583

# %%
positions = (tbl['x_peak'], tbl['y_peak'])
apertures = CircularAperture(positions, r=5.)
norm = simple_norm(data, 'sqrt', percent=99.9)
plt.imshow(data, cmap='Greys_r', origin='lower', norm=norm)
apertures.plot(color='#0547f9', lw=1.5)
plt.xlim(0, data.shape[1]-1)
plt.ylim(0, data.shape[0]-1)
